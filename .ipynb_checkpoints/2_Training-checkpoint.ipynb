# %% [markdown]
# # Computer Vision Nanodegree
#
# ## Project: Image Captioning
#
# ---
#
# In this notebook, you will train your CNN-RNN model.
#
# You are welcome and encouraged to try out many different architectures and hyperparameters when searching for a good model.
#
# This does have the potential to make the project quite messy!  Before submitting your project, make sure that you clean up:
# - the code you write in this notebook.  The notebook should describe how to train a single CNN-RNN architecture, corresponding to your final choice of hyperparameters.  You should structure the notebook so that the reviewer can replicate your results by running the code in this notebook.
# - the output of the code cell in **Step 2**.  The output should show the output obtained when training the model from scratch.
#
# This notebook **will be graded**.
#
# Feel free to use the links below to navigate the notebook:
# - [Step 1](#step1): Training Setup
# - [Step 2](#step2): Train your Model
# - [Step 3](#step3): (Optional) Validate your Model

# %% [markdown]
# <a id='step1'></a>
# ## Step 1: Training Setup
#
# In this step of the notebook, you will customize the training of your CNN-RNN model by specifying hyperparameters and setting other options that are important to the training procedure.  The values you set now will be used when training your model in **Step 2** below.
#
# You should only amend blocks of code that are preceded by a `TODO` statement.  **Any code blocks that are not preceded by a `TODO` statement should not be modified**.
#
# ### Task #1
#
# Begin by setting the following variables:
# - `batch_size` - the batch size of each training batch.  It is the number of image-caption pairs used to amend the model weights in each training step.
# - `vocab_threshold` - the minimum word count threshold.  Note that a larger threshold will result in a smaller vocabulary, whereas a smaller threshold will include rarer words and result in a larger vocabulary.
# - `vocab_from_file` - a Boolean that decides whether to load the vocabulary from file.
# - `embed_size` - the dimensionality of the image and word embeddings.
# - `hidden_size` - the number of features in the hidden state of the RNN decoder.
# - `num_epochs` - the number of epochs to train the model.  We recommend that you set `num_epochs=3`, but feel free to increase or decrease this number as you wish.  [This paper](https://arxiv.org/pdf/1502.03044.pdf) trained a captioning model on a single state-of-the-art GPU for 3 days, but you'll soon see that you can get reasonable results in a matter of a few hours!  (_But of course, if you want your model to compete with current research, you will have to train for much longer._)
# - `save_every` - determines how often to save the model weights.  We recommend that you set `save_every=1`, to save the model weights after each epoch.  This way, after the `i`th epoch, the encoder and decoder weights will be saved in the `models/` folder as `encoder-i.pkl` and `decoder-i.pkl`, respectively.
# - `print_every` - determines how often to print the batch loss to the Jupyter notebook while training.  Note that you **will not** observe a monotonic decrease in the loss function while training - this is perfectly fine and completely expected!  You are encouraged to keep this at its default value of `100` to avoid clogging the notebook, but feel free to change it.
# - `log_file` - the name of the text file containing - for every step - how the loss and perplexity evolved during training.
#
# If you're not sure where to begin to set some of the values above, you can peruse [this paper](https://arxiv.org/pdf/1502.03044.pdf) and [this paper](https://arxiv.org/pdf/1411.4555.pdf) for useful guidance!  **To avoid spending too long on this notebook**, you are encouraged to consult these suggested research papers to obtain a strong initial guess for which hyperparameters are likely to work best.  Then, train a single model, and proceed to the next notebook (**3_Inference.ipynb**).  If you are unhappy with your performance, you can return to this notebook to tweak the hyperparameters (and/or the architecture in **model.py**) and re-train your model.
#
# ### Question 1
#
# **Question:** Describe your CNN-RNN architecture in detail.  With this architecture in mind, how did you select the values of the variables in Task 1?  If you consulted a research paper detailing a successful implementation of an image captioning model, please provide the reference.
#
# **Answer:**
#
# * I used the CNN-RNN architecture of Show and Tell.
# * For the encoder, I originally use the `Resnet-50`, but had issues getting `Perplexity` down. So, I used a `Resnet-152` and added `batch-normalize layers`.
# * Reference (https://arxiv.org/pdf/1609.04836.pdf) proved that large batch-size affects the ability to generalise. Therefore, since the first attemp, I carried out training with batch-size of large, but I had not-good performance.
# * To solve this problem, I set `batch_size = 32` and I added `batch_first = True` for the *LSTM*.
# * In the decoder, I also used the `vocab_threshold = 5`, `embed_size = 512`, and `hidden_size = 512` (refer by the paper).
#
# ### (Optional) Task #2
#
# Note that we have provided a recommended image transform `transform_train` for pre-processing the training images, but you are welcome (and encouraged!) to modify it as you wish.  When modifying this transform, keep in mind that:
# - the images in the dataset have varying heights and widths, and
# - if using a pre-trained model, you must perform the corresponding appropriate normalization.
#
# ### Question 2
#
# **Question:** How did you select the transform in `transform_train`?  If you left the transform at its provided value, why do you think that it is a good choice for your CNN architecture?
#
# **Answer:**
#
#  Parameters of `transforms.Compose` for `transform_train`
# * transforms.Resize(256), transforms.RandomCrop(224) : The resize to 256 gives room for multiple 244 crops to improve generalisability.
# * transforms.RandomHorizontalFlip() : The random flips also help with this.
# * transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225)) : The normalize image for pre-trained model helps to keep the pixel values within the same range to improve accuracy.
#
# ### Task #3
#
# Next, you will specify a Python list containing the learnable parameters of the model.  For instance, if you decide to make all weights in the decoder trainable, but only want to train the weights in the embedding layer of the encoder, then you should set `params` to something like:
# ```
# params = list(decoder.parameters()) + list(encoder.embed.parameters())
# ```
#
# ### Question 3
#
# **Question:** How did you select the trainable parameters of your architecture?  Why do you think this is a good choice?
#
# **Answer:**
# * I used pre-tained parameters of `Resnet-152` for the encoder.
# * And, embedding layer and the decoder were only trained.
# * The training focus of the network should be learning the captions understanding images.
#
#
# ### Task #4
#
# Finally, you will select an [optimizer](http://pytorch.org/docs/master/optim.html#torch.optim.Optimizer).
#
# ### Question 4
#
# **Question:** How did you select the optimizer used to train your model?
#
# **Answer:**
# * For the optimiser, I used Adam with a learning rate of 0.001.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import transforms
import sys
#sys.path.append('/opt/cocoapi/PythonAPI')
sys.path.append('/home/hkkim/data/datasets/cocoapi/PythonAPI')
from pycocotools.coco import COCO
from data_loader import get_loader
from model import EncoderCNN, DecoderRNN
import math


## TODO #1: Select appropriate values for the Python variables below.
batch_size = 32          # batch size
vocab_threshold = 5        # minimum word count threshold
vocab_from_file = True    # if True, load existing vocab file
embed_size = 512           # dimensionality of image and word embeddings
hidden_size = 512          # number of features in hidden state of the RNN decoder
num_epochs = 3             # number of training epochs
save_every = 1             # determines frequency of saving model weights
print_every = 100          # determines window for printing average loss
log_file = 'training_log.txt'       # name of file with saved training loss and perplexity

# (Optional) TODO #2: Amend the image transform below.
transform_train = transforms.Compose([ 
    transforms.Resize(256),                          # smaller edge of image resized to 256
    transforms.RandomCrop(224),                      # get 224x224 crop from random location
    transforms.RandomHorizontalFlip(),               # horizontally flip image with probability=0.5
    transforms.ToTensor(),                           # convert the PIL Image to a tensor
    transforms.Normalize((0.485, 0.456, 0.406),      # normalize image for pre-trained model
                         (0.229, 0.224, 0.225))])

# Build data loader.
data_loader = get_loader(transform=transform_train,
                         mode='train',
                         batch_size=batch_size,
                         vocab_threshold=vocab_threshold,
                         vocab_from_file=vocab_from_file)

# The size of the vocabulary.
vocab_size = len(data_loader.dataset.vocab)

# Initialize the encoder and decoder. 
encoder = EncoderCNN(embed_size)
decoder = DecoderRNN(embed_size, hidden_size, vocab_size)

# Move models to GPU if CUDA is available. 
#device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Define the loss function. 
criterion = nn.CrossEntropyLoss().cuda() if torch.cuda.is_available() else nn.CrossEntropyLoss()

# TODO #3: Specify the learnable parameters of the model.
params = list(decoder.parameters()) + list(encoder.embed.parameters()) 

# Add parallel code
if torch.cuda.device_count() > 1:
    print("Let's use", torch.cuda.device_count(), "GPUs!")
    encoder = nn.DataParallel(encoder)
    decoder = nn.DataParallel(decoder)

encoder.to(device)
decoder.to(device)

# TODO #4: Define the optimizer.
optimizer = optim.Adam(params, lr=* For the optimiser, I used Adam with a learning rate of 0.001.)

# Set the total number of training steps per epoch.
total_step = math.ceil(len(data_loader.dataset.caption_lengths) / data_loader.batch_sampler.batch_size)
# Out:
# Vocabulary successfully loaded from vocab.pkl file!
# loading annotations into memory...
# Done (t=0.59s)
# creating index...
#   0%|          | 784/414113 [00:00<00:52, 7831.94it/s]
# index created!
# Obtaining caption lengths...
# 100%|██████████| 414113/414113 [00:44<00:00, 9254.12it/s]
# Let's use 4 GPUs!

# %% [markdown]
# <a id='step2'></a>
# ## Step 2: Train your Model
#
# Once you have executed the code cell in **Step 1**, the training procedure below should run without issue.
#
# It is completely fine to leave the code cell below as-is without modifications to train your model.  However, if you would like to modify the code used to train the model below, you must ensure that your changes are easily parsed by your reviewer.  In other words, make sure to provide appropriate comments to describe how your code works!
#
# You may find it useful to load saved weights to resume training.  In that case, note the names of the files containing the encoder and decoder weights that you'd like to load (`encoder_file` and `decoder_file`).  Then you can load the weights by using the lines below:
#
# ```python
# # Load pre-trained weights before resuming training.
# encoder.load_state_dict(torch.load(os.path.join('./models', encoder_file)))
# decoder.load_state_dict(torch.load(os.path.join('./models', decoder_file)))
# ```
#
# While trying out parameters, make sure to take extensive notes and record the settings that you used in your various training runs.  In particular, you don't want to encounter a situation where you've trained a model for several hours but can't remember what settings you used :).
#
# ### A Note on Tuning Hyperparameters
#
# To figure out how well your model is doing, you can look at how the training loss and perplexity evolve during training - and for the purposes of this project, you are encouraged to amend the hyperparameters based on this information.
#
# However, this will not tell you if your model is overfitting to the training data, and, unfortunately, overfitting is a problem that is commonly encountered when training image captioning models.
#
# For this project, you need not worry about overfitting. **This project does not have strict requirements regarding the performance of your model**, and you just need to demonstrate that your model has learned **_something_** when you generate captions on the test data.  For now, we strongly encourage you to train your model for the suggested 3 epochs without worrying about performance; then, you should immediately transition to the next notebook in the sequence (**3_Inference.ipynb**) to see how your model performs on the test data.  If your model needs to be changed, you can come back to this notebook, amend hyperparameters (if necessary), and re-train the model.
#
# That said, if you would like to go above and beyond in this project, you can read about some approaches to minimizing overfitting in section 4.3.1 of [this paper](http://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=7505636).  In the next (optional) step of this notebook, we provide some guidance for assessing the performance on the validation dataset.

# %%
import torch.utils.data as data
import numpy as np
import os
import requests
import time

# Open the training log file.
f = open(log_file, 'w')

old_time = time.time()
"""
response = requests.request("GET", 
                            "http://metadata.google.internal/computeMetadata/v1/instance/attributes/keep_alive_token", 
                            headers={"Metadata-Flavor":"Google"})
"""
response_text = "id6ae0xid5k2ys6f8r7q3awg2ofm30tw"

for epoch in range(1, num_epochs+1):
    
    for i_step in range(1, total_step+1):
        
        """
        if time.time() - old_time > 60:
            old_time = time.time()
            requests.request("POST", 
                             "https://nebula.udacity.com/api/v1/remote/keep-alive", 
                             headers={'Authorization': "STAR " + response.text})
        """
        if time.time() - old_time > 60:
            old_time = time.time()
            requests.request("POST", 
                             "https://nebula.udacity.com/api/v1/remote/keep-alive", 
                             headers={'Authorization': "STAR " + response_text})
        
        # Randomly sample a caption length, and sample indices with that length.
        indices = data_loader.dataset.get_train_indices()
        # Create and assign a batch sampler to retrieve a batch with the sampled indices.
        new_sampler = data.sampler.SubsetRandomSampler(indices=indices)
        data_loader.batch_sampler.sampler = new_sampler
        
        # Obtain the batch.
        images, captions = next(iter(data_loader))

        # Move batch of images and captions to GPU if CUDA is available.
        images = images.to(device)
        captions = captions.to(device)
        
        # Zero the gradients.
        decoder.zero_grad()
        encoder.zero_grad()
        
        # Pass the inputs through the CNN-RNN model.
        features = encoder(images)
        outputs = decoder(features, captions)
        
        # Calculate the batch loss.
        loss = criterion(outputs.view(-1, vocab_size), captions.view(-1))
        
        # Backward pass.
        loss.backward()
        
        # Update the parameters in the optimizer.
        optimizer.step()
            
        # Get training statistics.
        stats = 'Epoch [%d/%d], Step [%d/%d], Loss: %.4f, Perplexity: %5.4f' % (epoch, num_epochs, i_step, total_step, loss.item(), np.exp(loss.item()))
        
        # Print training statistics (on same line).
        print('\r' + stats, end="")
        sys.stdout.flush()
        
        # Print training statistics to file.
        f.write(stats + '\n')
        f.flush()
        
        # Print training statistics (on different line).
        if i_step % print_every == 0:
            print('\r' + stats)
            
    # Save the weights.
    if epoch % save_every == 0:
        torch.save(decoder.state_dict(), os.path.join('./models', 'decoder-%d.pkl' % epoch))
        torch.save(encoder.state_dict(), os.path.join('./models', 'encoder-%d.pkl' % epoch))

# Close the training log file.
f.close()
# Out:
# /home/hkkim/data/datasets/cocoapi/Image_Captioning/model.py:36: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
#   hiddens, _ = self.lstm(embeddings)
# Epoch [1/3], Step [100/12942], Loss: 3.6784, Perplexity: 39.5819
# Epoch [1/3], Step [200/12942], Loss: 3.4551, Perplexity: 31.6630
# Epoch [1/3], Step [300/12942], Loss: 3.3128, Perplexity: 27.4613
# Epoch [1/3], Step [400/12942], Loss: 3.3566, Perplexity: 28.6911
# Epoch [1/3], Step [500/12942], Loss: 3.0833, Perplexity: 21.8305
# Epoch [1/3], Step [600/12942], Loss: 2.7698, Perplexity: 15.9552
# Epoch [1/3], Step [700/12942], Loss: 2.9825, Perplexity: 19.7379
# Epoch [1/3], Step [800/12942], Loss: 2.8360, Perplexity: 17.0481
# Epoch [1/3], Step [900/12942], Loss: 3.0388, Perplexity: 20.8808
# Epoch [1/3], Step [1000/12942], Loss: 2.9703, Perplexity: 19.4977
# Epoch [1/3], Step [1100/12942], Loss: 2.5107, Perplexity: 12.3134
# Epoch [1/3], Step [1200/12942], Loss: 2.6397, Perplexity: 14.0085
# Epoch [1/3], Step [1300/12942], Loss: 2.7428, Perplexity: 15.5305
# Epoch [1/3], Step [1400/12942], Loss: 2.9808, Perplexity: 19.7043
# Epoch [1/3], Step [1500/12942], Loss: 2.5858, Perplexity: 13.2732
# Epoch [1/3], Step [1600/12942], Loss: 2.5747, Perplexity: 13.1275
# Epoch [1/3], Step [1700/12942], Loss: 2.8969, Perplexity: 18.1187
# Epoch [1/3], Step [1800/12942], Loss: 2.3638, Perplexity: 10.6315
# Epoch [1/3], Step [1900/12942], Loss: 2.4710, Perplexity: 11.8344
# Epoch [1/3], Step [2000/12942], Loss: 2.2889, Perplexity: 9.86435
# Epoch [1/3], Step [2100/12942], Loss: 2.5417, Perplexity: 12.7011
# Epoch [1/3], Step [2200/12942], Loss: 2.4743, Perplexity: 11.8728
# Epoch [1/3], Step [2300/12942], Loss: 2.5826, Perplexity: 13.2317
# Epoch [1/3], Step [2400/12942], Loss: 3.0178, Perplexity: 20.4470
# Epoch [1/3], Step [2500/12942], Loss: 2.2464, Perplexity: 9.45333
# Epoch [1/3], Step [2600/12942], Loss: 2.8990, Perplexity: 18.1565
# Epoch [1/3], Step [2700/12942], Loss: 2.3511, Perplexity: 10.4975
# Epoch [1/3], Step [2800/12942], Loss: 3.0701, Perplexity: 21.5449
# Epoch [1/3], Step [2900/12942], Loss: 2.4853, Perplexity: 12.0048
# Epoch [1/3], Step [3000/12942], Loss: 2.4234, Perplexity: 11.28369
# Epoch [1/3], Step [3100/12942], Loss: 2.4170, Perplexity: 11.2120
# Epoch [1/3], Step [3200/12942], Loss: 2.1488, Perplexity: 8.57447
# Epoch [1/3], Step [3300/12942], Loss: 2.4664, Perplexity: 11.7799
# Epoch [1/3], Step [3400/12942], Loss: 2.3949, Perplexity: 10.9669
# Epoch [1/3], Step [3500/12942], Loss: 2.4688, Perplexity: 11.8086
# Epoch [1/3], Step [3600/12942], Loss: 2.2075, Perplexity: 9.09338
# Epoch [1/3], Step [3700/12942], Loss: 2.2810, Perplexity: 9.78687
# Epoch [1/3], Step [3800/12942], Loss: 2.7875, Perplexity: 16.2410
# Epoch [1/3], Step [3900/12942], Loss: 2.4138, Perplexity: 11.1762
# Epoch [1/3], Step [4000/12942], Loss: 1.9687, Perplexity: 7.16147
# Epoch [1/3], Step [4100/12942], Loss: 2.0438, Perplexity: 7.71959
# Epoch [1/3], Step [4200/12942], Loss: 2.3818, Perplexity: 10.8249
# Epoch [1/3], Step [4300/12942], Loss: 2.7965, Perplexity: 16.3864
# Epoch [1/3], Step [4400/12942], Loss: 2.1152, Perplexity: 8.29088
# Epoch [1/3], Step [4500/12942], Loss: 2.4882, Perplexity: 12.0392
# Epoch [1/3], Step [4600/12942], Loss: 2.6308, Perplexity: 13.8847
# Epoch [1/3], Step [4700/12942], Loss: 2.4776, Perplexity: 11.9126
# Epoch [1/3], Step [4800/12942], Loss: 2.3115, Perplexity: 10.0891
# Epoch [1/3], Step [4900/12942], Loss: 2.2192, Perplexity: 9.20037
# Epoch [1/3], Step [5000/12942], Loss: 2.1077, Perplexity: 8.22967
# Epoch [1/3], Step [5100/12942], Loss: 2.8580, Perplexity: 17.42605
# Epoch [1/3], Step [5200/12942], Loss: 2.6990, Perplexity: 14.8641
# Epoch [1/3], Step [5300/12942], Loss: 2.4436, Perplexity: 11.5149
# Epoch [1/3], Step [5400/12942], Loss: 2.3923, Perplexity: 10.9388
# Epoch [1/3], Step [5500/12942], Loss: 2.1887, Perplexity: 8.92366
# Epoch [1/3], Step [5600/12942], Loss: 2.2557, Perplexity: 9.54201
# Epoch [1/3], Step [5700/12942], Loss: 2.0985, Perplexity: 8.15385
# Epoch [1/3], Step [5800/12942], Loss: 2.1622, Perplexity: 8.69006
# Epoch [1/3], Step [5900/12942], Loss: 2.1128, Perplexity: 8.27137
# Epoch [1/3], Step [6000/12942], Loss: 2.2807, Perplexity: 9.78305
# Epoch [1/3], Step [6100/12942], Loss: 2.0252, Perplexity: 7.57742
# Epoch [1/3], Step [6200/12942], Loss: 2.3179, Perplexity: 10.1542
# Epoch [1/3], Step [6300/12942], Loss: 2.3284, Perplexity: 10.2615
# Epoch [1/3], Step [6400/12942], Loss: 2.5935, Perplexity: 13.3770
# Epoch [1/3], Step [6500/12942], Loss: 2.2120, Perplexity: 9.13389
# Epoch [1/3], Step [6600/12942], Loss: 2.3584, Perplexity: 10.5740
# Epoch [1/3], Step [6700/12942], Loss: 2.0717, Perplexity: 7.93816
# Epoch [1/3], Step [6800/12942], Loss: 2.2738, Perplexity: 9.71581
# Epoch [1/3], Step [6900/12942], Loss: 2.1100, Perplexity: 8.24850
# Epoch [1/3], Step [7000/12942], Loss: 2.8128, Perplexity: 16.6568
# Epoch [1/3], Step [7100/12942], Loss: 2.0630, Perplexity: 7.86925
# Epoch [1/3], Step [7200/12942], Loss: 2.3645, Perplexity: 10.6384
# Epoch [1/3], Step [7300/12942], Loss: 2.3575, Perplexity: 10.5640
# Epoch [1/3], Step [7400/12942], Loss: 2.7184, Perplexity: 15.1562
# Epoch [1/3], Step [7500/12942], Loss: 2.5501, Perplexity: 12.8089
# Epoch [1/3], Step [7600/12942], Loss: 2.3971, Perplexity: 10.9910
# Epoch [1/3], Step [7700/12942], Loss: 2.3767, Perplexity: 10.7696
# Epoch [1/3], Step [7800/12942], Loss: 2.7867, Perplexity: 16.2277
# Epoch [1/3], Step [7900/12942], Loss: 2.1578, Perplexity: 8.65257
# Epoch [1/3], Step [8000/12942], Loss: 2.1405, Perplexity: 8.50388
# Epoch [1/3], Step [8100/12942], Loss: 2.1136, Perplexity: 8.27770
# Epoch [1/3], Step [8200/12942], Loss: 2.1095, Perplexity: 8.24452
# Epoch [1/3], Step [8300/12942], Loss: 2.0430, Perplexity: 7.71379
# Epoch [1/3], Step [8400/12942], Loss: 3.2381, Perplexity: 25.4843
# Epoch [1/3], Step [8500/12942], Loss: 2.0875, Perplexity: 8.06450
# Epoch [1/3], Step [8600/12942], Loss: 2.2738, Perplexity: 9.71607
# Epoch [1/3], Step [8700/12942], Loss: 2.1462, Perplexity: 8.55212
# Epoch [1/3], Step [8800/12942], Loss: 2.6373, Perplexity: 13.9758
# Epoch [1/3], Step [8900/12942], Loss: 2.0724, Perplexity: 7.94412
# Epoch [1/3], Step [9000/12942], Loss: 1.9771, Perplexity: 7.22147
# Epoch [1/3], Step [9100/12942], Loss: 2.0729, Perplexity: 7.94808
# Epoch [1/3], Step [9200/12942], Loss: 2.6175, Perplexity: 13.7012
# Epoch [1/3], Step [9300/12942], Loss: 2.1341, Perplexity: 8.44989
# Epoch [1/3], Step [9400/12942], Loss: 2.5507, Perplexity: 12.8155
# Epoch [1/3], Step [9500/12942], Loss: 2.3677, Perplexity: 10.6729
# Epoch [1/3], Step [9600/12942], Loss: 1.9870, Perplexity: 7.29354
# Epoch [1/3], Step [9700/12942], Loss: 2.0123, Perplexity: 7.48059
# Epoch [1/3], Step [9800/12942], Loss: 2.1307, Perplexity: 8.42114
# Epoch [1/3], Step [9900/12942], Loss: 1.7781, Perplexity: 5.91874
# Epoch [1/3], Step [10000/12942], Loss: 1.9503, Perplexity: 7.0309
# Epoch [1/3], Step [10100/12942], Loss: 1.9769, Perplexity: 7.22068
# Epoch [1/3], Step [10200/12942], Loss: 2.5493, Perplexity: 12.7986
# Epoch [1/3], Step [10300/12942], Loss: 2.0041, Perplexity: 7.41962
# Epoch [1/3], Step [10400/12942], Loss: 2.2528, Perplexity: 9.51442
# Epoch [1/3], Step [10500/12942], Loss: 2.3847, Perplexity: 10.8559
# Epoch [1/3], Step [10600/12942], Loss: 1.9720, Perplexity: 7.18536
# Epoch [1/3], Step [10700/12942], Loss: 2.2157, Perplexity: 9.16755
# Epoch [1/3], Step [10800/12942], Loss: 2.9004, Perplexity: 18.1819
# Epoch [1/3], Step [10900/12942], Loss: 2.0681, Perplexity: 7.90954
# Epoch [1/3], Step [11000/12942], Loss: 2.2819, Perplexity: 9.79576
# Epoch [1/3], Step [11100/12942], Loss: 1.9166, Perplexity: 6.79753
# Epoch [1/3], Step [11200/12942], Loss: 2.2876, Perplexity: 9.85162
# Epoch [1/3], Step [11300/12942], Loss: 1.8713, Perplexity: 6.49645
# Epoch [1/3], Step [11400/12942], Loss: 1.9899, Perplexity: 7.31453
# Epoch [1/3], Step [11500/12942], Loss: 1.9333, Perplexity: 6.912236
# Epoch [1/3], Step [11600/12942], Loss: 2.3121, Perplexity: 10.0959
# Epoch [1/3], Step [11700/12942], Loss: 1.9304, Perplexity: 6.89243
# Epoch [1/3], Step [11800/12942], Loss: 2.1569, Perplexity: 8.64404
# Epoch [1/3], Step [11900/12942], Loss: 1.9654, Perplexity: 7.13763
# Epoch [1/3], Step [12000/12942], Loss: 2.0111, Perplexity: 7.47140
# Epoch [1/3], Step [12100/12942], Loss: 2.1125, Perplexity: 8.26884
# Epoch [1/3], Step [12200/12942], Loss: 2.2616, Perplexity: 9.59835
# Epoch [1/3], Step [12300/12942], Loss: 2.4391, Perplexity: 11.4622
# Epoch [1/3], Step [12400/12942], Loss: 1.9731, Perplexity: 7.19283
# Epoch [1/3], Step [12500/12942], Loss: 1.8196, Perplexity: 6.16943
# Epoch [1/3], Step [12600/12942], Loss: 2.2886, Perplexity: 9.86133
# Epoch [1/3], Step [12700/12942], Loss: 2.5488, Perplexity: 12.7924
# Epoch [1/3], Step [12800/12942], Loss: 2.1132, Perplexity: 8.27504
# Epoch [1/3], Step [12900/12942], Loss: 2.3033, Perplexity: 10.0076
# Epoch [2/3], Step [100/12942], Loss: 1.8526, Perplexity: 6.3766927
# Epoch [2/3], Step [200/12942], Loss: 2.3895, Perplexity: 10.9078
# Epoch [2/3], Step [300/12942], Loss: 2.1035, Perplexity: 8.19514
# Epoch [2/3], Step [400/12942], Loss: 1.8313, Perplexity: 6.24229
# Epoch [2/3], Step [500/12942], Loss: 2.1670, Perplexity: 8.73160
# Epoch [2/3], Step [600/12942], Loss: 2.8974, Perplexity: 18.1278
# Epoch [2/3], Step [700/12942], Loss: 1.8916, Perplexity: 6.62977
# Epoch [2/3], Step [800/12942], Loss: 2.0916, Perplexity: 8.09791
# Epoch [2/3], Step [900/12942], Loss: 2.3025, Perplexity: 9.99961
# Epoch [2/3], Step [1000/12942], Loss: 2.0807, Perplexity: 8.0097
# Epoch [2/3], Step [1100/12942], Loss: 2.1370, Perplexity: 8.47431
# Epoch [2/3], Step [1200/12942], Loss: 1.9733, Perplexity: 7.19461
# Epoch [2/3], Step [1300/12942], Loss: 1.9827, Perplexity: 7.26217
# Epoch [2/3], Step [1400/12942], Loss: 1.8672, Perplexity: 6.47000
# Epoch [2/3], Step [1500/12942], Loss: 2.2101, Perplexity: 9.11663
# Epoch [2/3], Step [1600/12942], Loss: 2.2300, Perplexity: 9.29961
# Epoch [2/3], Step [1700/12942], Loss: 2.2258, Perplexity: 9.26081
# Epoch [2/3], Step [1800/12942], Loss: 2.1012, Perplexity: 8.17644
# Epoch [2/3], Step [1900/12942], Loss: 2.0704, Perplexity: 7.92774
# Epoch [2/3], Step [2000/12942], Loss: 1.9998, Perplexity: 7.38737
# Epoch [2/3], Step [2100/12942], Loss: 1.9383, Perplexity: 6.94676
# Epoch [2/3], Step [2200/12942], Loss: 2.8359, Perplexity: 17.0449
# Epoch [2/3], Step [2300/12942], Loss: 1.9238, Perplexity: 6.84721
# Epoch [2/3], Step [2400/12942], Loss: 1.9688, Perplexity: 7.16236
# Epoch [2/3], Step [2500/12942], Loss: 1.9238, Perplexity: 6.84681
# Epoch [2/3], Step [2600/12942], Loss: 1.9454, Perplexity: 6.99661
# Epoch [2/3], Step [2700/12942], Loss: 2.2400, Perplexity: 9.39290
# Epoch [2/3], Step [2800/12942], Loss: 1.8713, Perplexity: 6.49682
# Epoch [2/3], Step [2900/12942], Loss: 2.0616, Perplexity: 7.85843
# Epoch [2/3], Step [3000/12942], Loss: 2.3123, Perplexity: 10.0975
# Epoch [2/3], Step [3100/12942], Loss: 2.0275, Perplexity: 7.59535
# Epoch [2/3], Step [3200/12942], Loss: 1.8837, Perplexity: 6.57794
# Epoch [2/3], Step [3300/12942], Loss: 2.0947, Perplexity: 8.12280
# Epoch [2/3], Step [3400/12942], Loss: 1.9473, Perplexity: 7.00964
# Epoch [2/3], Step [3500/12942], Loss: 1.9696, Perplexity: 7.16829
# Epoch [2/3], Step [3600/12942], Loss: 2.0882, Perplexity: 8.07055
# Epoch [2/3], Step [3700/12942], Loss: 2.0102, Perplexity: 7.46500
# Epoch [2/3], Step [3800/12942], Loss: 2.2279, Perplexity: 9.28057
# Epoch [2/3], Step [3900/12942], Loss: 2.6550, Perplexity: 14.2247
# Epoch [2/3], Step [4000/12942], Loss: 2.7834, Perplexity: 16.1733
# Epoch [2/3], Step [4100/12942], Loss: 1.8129, Perplexity: 6.12840
# Epoch [2/3], Step [4200/12942], Loss: 2.1790, Perplexity: 8.83780
# Epoch [2/3], Step [4300/12942], Loss: 1.9152, Perplexity: 6.78868
# Epoch [2/3], Step [4400/12942], Loss: 1.9901, Perplexity: 7.31642
# Epoch [2/3], Step [4500/12942], Loss: 2.9961, Perplexity: 20.0076
# Epoch [2/3], Step [4600/12942], Loss: 1.8553, Perplexity: 6.39362
# Epoch [2/3], Step [4700/12942], Loss: 1.8029, Perplexity: 6.06703
# Epoch [2/3], Step [4800/12942], Loss: 1.8358, Perplexity: 6.26983
# Epoch [2/3], Step [4900/12942], Loss: 2.1404, Perplexity: 8.50288
# Epoch [2/3], Step [5000/12942], Loss: 2.0295, Perplexity: 7.61065
# Epoch [2/3], Step [5100/12942], Loss: 2.1791, Perplexity: 8.838544
# Epoch [2/3], Step [5200/12942], Loss: 1.7471, Perplexity: 5.73827
# Epoch [2/3], Step [5300/12942], Loss: 1.9831, Perplexity: 7.26516
# Epoch [2/3], Step [5400/12942], Loss: 2.0583, Perplexity: 7.83239
# Epoch [2/3], Step [5500/12942], Loss: 2.2913, Perplexity: 9.88794
# Epoch [2/3], Step [5600/12942], Loss: 1.9498, Perplexity: 7.02741
# Epoch [2/3], Step [5700/12942], Loss: 2.0493, Perplexity: 7.76273
# Epoch [2/3], Step [5800/12942], Loss: 2.1542, Perplexity: 8.62107
# Epoch [2/3], Step [5900/12942], Loss: 1.8751, Perplexity: 6.52135
# Epoch [2/3], Step [6000/12942], Loss: 1.8710, Perplexity: 6.49462
# Epoch [2/3], Step [6100/12942], Loss: 1.8866, Perplexity: 6.59675
# Epoch [2/3], Step [6200/12942], Loss: 2.0442, Perplexity: 7.72287
# Epoch [2/3], Step [6300/12942], Loss: 2.4752, Perplexity: 11.8846
# Epoch [2/3], Step [6400/12942], Loss: 2.0288, Perplexity: 7.60517
# Epoch [2/3], Step [6500/12942], Loss: 1.7359, Perplexity: 5.67419
# Epoch [2/3], Step [6600/12942], Loss: 2.0564, Perplexity: 7.81819
# Epoch [2/3], Step [6700/12942], Loss: 2.1768, Perplexity: 8.817760
# Epoch [2/3], Step [6800/12942], Loss: 2.1356, Perplexity: 8.46175
# Epoch [2/3], Step [6900/12942], Loss: 1.9596, Perplexity: 7.09686
# Epoch [2/3], Step [7000/12942], Loss: 2.7428, Perplexity: 15.5297
# Epoch [2/3], Step [7100/12942], Loss: 2.0696, Perplexity: 7.92188
# Epoch [2/3], Step [7200/12942], Loss: 1.9218, Perplexity: 6.83307
# Epoch [2/3], Step [7300/12942], Loss: 2.6628, Perplexity: 14.3366
# Epoch [2/3], Step [7400/12942], Loss: 2.4409, Perplexity: 11.4831
# Epoch [2/3], Step [7500/12942], Loss: 2.0455, Perplexity: 7.73320
# Epoch [2/3], Step [7600/12942], Loss: 1.8412, Perplexity: 6.30401
# Epoch [2/3], Step [7700/12942], Loss: 2.0385, Perplexity: 7.67936
# Epoch [2/3], Step [7800/12942], Loss: 2.1508, Perplexity: 8.59180
# Epoch [2/3], Step [7900/12942], Loss: 2.5735, Perplexity: 13.1122
# Epoch [2/3], Step [8000/12942], Loss: 1.8627, Perplexity: 6.44132
# Epoch [2/3], Step [8100/12942], Loss: 2.3093, Perplexity: 10.0677
# Epoch [2/3], Step [8200/12942], Loss: 2.0400, Perplexity: 7.69081
# Epoch [2/3], Step [8300/12942], Loss: 1.8407, Perplexity: 6.30116
# Epoch [2/3], Step [8400/12942], Loss: 2.1483, Perplexity: 8.57010
# Epoch [2/3], Step [8500/12942], Loss: 1.9071, Perplexity: 6.73360
# Epoch [2/3], Step [8600/12942], Loss: 2.3742, Perplexity: 10.7426
# Epoch [2/3], Step [8700/12942], Loss: 2.4115, Perplexity: 11.1505
# Epoch [2/3], Step [8800/12942], Loss: 2.0931, Perplexity: 8.11008
# Epoch [2/3], Step [8900/12942], Loss: 1.8783, Perplexity: 6.54246
# Epoch [2/3], Step [9000/12942], Loss: 2.1028, Perplexity: 8.18946
# Epoch [2/3], Step [9100/12942], Loss: 2.0087, Perplexity: 7.45389
# Epoch [2/3], Step [9200/12942], Loss: 1.7526, Perplexity: 5.76981
# Epoch [2/3], Step [9300/12942], Loss: 2.1298, Perplexity: 8.41328
# Epoch [2/3], Step [9400/12942], Loss: 2.5110, Perplexity: 12.3175
# Epoch [2/3], Step [9500/12942], Loss: 2.0833, Perplexity: 8.03091
# Epoch [2/3], Step [9600/12942], Loss: 2.1184, Perplexity: 8.31775
# Epoch [2/3], Step [9700/12942], Loss: 2.0057, Perplexity: 7.43162
# Epoch [2/3], Step [9800/12942], Loss: 2.0998, Perplexity: 8.16428
# Epoch [2/3], Step [9900/12942], Loss: 1.6001, Perplexity: 4.95338
# Epoch [2/3], Step [10000/12942], Loss: 1.8397, Perplexity: 6.2944
# Epoch [2/3], Step [10100/12942], Loss: 2.0966, Perplexity: 8.13874
# Epoch [2/3], Step [10200/12942], Loss: 1.6828, Perplexity: 5.38042
# Epoch [2/3], Step [10300/12942], Loss: 2.2665, Perplexity: 9.64598
# Epoch [2/3], Step [10400/12942], Loss: 2.1990, Perplexity: 9.01588
# Epoch [2/3], Step [10500/12942], Loss: 1.9066, Perplexity: 6.730495
# Epoch [2/3], Step [10600/12942], Loss: 1.8878, Perplexity: 6.60486
# Epoch [2/3], Step [10700/12942], Loss: 1.8590, Perplexity: 6.41738
# Epoch [2/3], Step [10800/12942], Loss: 1.9031, Perplexity: 6.70696
# Epoch [2/3], Step [10900/12942], Loss: 1.7767, Perplexity: 5.91019
# Epoch [2/3], Step [11000/12942], Loss: 1.9152, Perplexity: 6.78860
# Epoch [2/3], Step [11100/12942], Loss: 2.3202, Perplexity: 10.17764
# Epoch [2/3], Step [11200/12942], Loss: 2.2077, Perplexity: 9.09487
# Epoch [2/3], Step [11300/12942], Loss: 2.6240, Perplexity: 13.7912
# Epoch [2/3], Step [11400/12942], Loss: 2.1972, Perplexity: 8.99932
# Epoch [2/3], Step [11500/12942], Loss: 1.8828, Perplexity: 6.57202
# Epoch [2/3], Step [11600/12942], Loss: 1.8524, Perplexity: 6.37494
# Epoch [2/3], Step [11700/12942], Loss: 1.9449, Perplexity: 6.99267
# Epoch [2/3], Step [11800/12942], Loss: 1.9675, Perplexity: 7.15258
# Epoch [2/3], Step [11900/12942], Loss: 2.4061, Perplexity: 11.0909
# Epoch [2/3], Step [12000/12942], Loss: 2.1304, Perplexity: 8.41860
# Epoch [2/3], Step [12100/12942], Loss: 2.0495, Perplexity: 7.76415
# Epoch [2/3], Step [12200/12942], Loss: 1.8862, Perplexity: 6.59417
# Epoch [2/3], Step [12300/12942], Loss: 1.9675, Perplexity: 7.15301
# Epoch [2/3], Step [12400/12942], Loss: 2.1596, Perplexity: 8.66798
# Epoch [2/3], Step [12500/12942], Loss: 1.9760, Perplexity: 7.21415
# Epoch [2/3], Step [12600/12942], Loss: 1.8623, Perplexity: 6.43889
# Epoch [2/3], Step [12700/12942], Loss: 1.9836, Perplexity: 7.26916
# Epoch [2/3], Step [12800/12942], Loss: 1.9664, Perplexity: 7.14484
# Epoch [2/3], Step [12900/12942], Loss: 1.8133, Perplexity: 6.13059
# Epoch [3/3], Step [100/12942], Loss: 2.2799, Perplexity: 9.7757562
# Epoch [3/3], Step [200/12942], Loss: 1.8399, Perplexity: 6.29585
# Epoch [3/3], Step [300/12942], Loss: 1.8437, Perplexity: 6.31992
# Epoch [3/3], Step [400/12942], Loss: 1.9540, Perplexity: 7.05728
# Epoch [3/3], Step [500/12942], Loss: 2.2740, Perplexity: 9.71807
# Epoch [3/3], Step [600/12942], Loss: 1.9203, Perplexity: 6.82309
# Epoch [3/3], Step [700/12942], Loss: 1.8042, Perplexity: 6.07501
# Epoch [3/3], Step [800/12942], Loss: 2.2370, Perplexity: 9.36535
# Epoch [3/3], Step [900/12942], Loss: 2.2243, Perplexity: 9.24733
# Epoch [3/3], Step [1000/12942], Loss: 2.0180, Perplexity: 7.5230
# Epoch [3/3], Step [1100/12942], Loss: 1.9967, Perplexity: 7.36477
# Epoch [3/3], Step [1200/12942], Loss: 2.1721, Perplexity: 8.77655
# Epoch [3/3], Step [1300/12942], Loss: 1.9409, Perplexity: 6.96521
# Epoch [3/3], Step [1400/12942], Loss: 2.8732, Perplexity: 17.6939
# Epoch [3/3], Step [1500/12942], Loss: 2.0369, Perplexity: 7.66711
# Epoch [3/3], Step [1600/12942], Loss: 1.6805, Perplexity: 5.36825
# Epoch [3/3], Step [1700/12942], Loss: 2.2366, Perplexity: 9.36190
# Epoch [3/3], Step [1800/12942], Loss: 1.8400, Perplexity: 6.29654
# Epoch [3/3], Step [1900/12942], Loss: 2.0374, Perplexity: 7.67047
# Epoch [3/3], Step [2000/12942], Loss: 1.8327, Perplexity: 6.25067
# Epoch [3/3], Step [2100/12942], Loss: 2.2060, Perplexity: 9.079354
# Epoch [3/3], Step [2200/12942], Loss: 2.1159, Perplexity: 8.29736
# Epoch [3/3], Step [2300/12942], Loss: 2.0944, Perplexity: 8.12027
# Epoch [3/3], Step [2400/12942], Loss: 2.0881, Perplexity: 8.06952
# Epoch [3/3], Step [2500/12942], Loss: 2.4395, Perplexity: 11.4671
# Epoch [3/3], Step [2600/12942], Loss: 2.0980, Perplexity: 8.15003
# Epoch [3/3], Step [2700/12942], Loss: 2.0496, Perplexity: 7.76519
# Epoch [3/3], Step [2800/12942], Loss: 1.7890, Perplexity: 5.98364
# Epoch [3/3], Step [2900/12942], Loss: 1.7875, Perplexity: 5.97461
# Epoch [3/3], Step [3000/12942], Loss: 2.4906, Perplexity: 12.0681
# Epoch [3/3], Step [3100/12942], Loss: 2.1318, Perplexity: 8.43033
# Epoch [3/3], Step [3200/12942], Loss: 2.0003, Perplexity: 7.39115
# Epoch [3/3], Step [3300/12942], Loss: 1.7712, Perplexity: 5.87776
# Epoch [3/3], Step [3400/12942], Loss: 2.1317, Perplexity: 8.42944
# Epoch [3/3], Step [3500/12942], Loss: 2.3446, Perplexity: 10.4288
# Epoch [3/3], Step [3600/12942], Loss: 1.7369, Perplexity: 5.67988
# Epoch [3/3], Step [3700/12942], Loss: 1.7557, Perplexity: 5.78766
# Epoch [3/3], Step [3800/12942], Loss: 1.6332, Perplexity: 5.12035
# Epoch [3/3], Step [3900/12942], Loss: 1.9863, Perplexity: 7.28876
# Epoch [3/3], Step [4000/12942], Loss: 2.0229, Perplexity: 7.56035
# Epoch [3/3], Step [4100/12942], Loss: 2.3108, Perplexity: 10.0823
# Epoch [3/3], Step [4200/12942], Loss: 1.8661, Perplexity: 6.46278
# Epoch [3/3], Step [4300/12942], Loss: 1.6143, Perplexity: 5.02433
# Epoch [3/3], Step [4400/12942], Loss: 2.0192, Perplexity: 7.53269
# Epoch [3/3], Step [4500/12942], Loss: 2.0661, Perplexity: 7.89401
# Epoch [3/3], Step [4600/12942], Loss: 1.8875, Perplexity: 6.60292
# Epoch [3/3], Step [4700/12942], Loss: 1.9307, Perplexity: 6.89407
# Epoch [3/3], Step [4800/12942], Loss: 1.8779, Perplexity: 6.53943
# Epoch [3/3], Step [4900/12942], Loss: 2.1948, Perplexity: 8.97793
# Epoch [3/3], Step [5000/12942], Loss: 1.8557, Perplexity: 6.39639
# Epoch [3/3], Step [5100/12942], Loss: 1.8131, Perplexity: 6.12921
# Epoch [3/3], Step [5200/12942], Loss: 2.0677, Perplexity: 7.90647
# Epoch [3/3], Step [5300/12942], Loss: 1.7131, Perplexity: 5.54622
# Epoch [3/3], Step [5400/12942], Loss: 1.9998, Perplexity: 7.38788
# Epoch [3/3], Step [5500/12942], Loss: 2.0201, Perplexity: 7.53946
# Epoch [3/3], Step [5600/12942], Loss: 2.0914, Perplexity: 8.09609
# Epoch [3/3], Step [5700/12942], Loss: 1.6941, Perplexity: 5.44176
# Epoch [3/3], Step [5800/12942], Loss: 2.0763, Perplexity: 7.97476
# Epoch [3/3], Step [5900/12942], Loss: 1.9622, Perplexity: 7.11539
# Epoch [3/3], Step [6000/12942], Loss: 1.9478, Perplexity: 7.01302
# Epoch [3/3], Step [6100/12942], Loss: 1.8250, Perplexity: 6.20262
# Epoch [3/3], Step [6200/12942], Loss: 1.8897, Perplexity: 6.61779
# Epoch [3/3], Step [6300/12942], Loss: 1.9627, Perplexity: 7.11831
# Epoch [3/3], Step [6400/12942], Loss: 1.7845, Perplexity: 5.95673
# Epoch [3/3], Step [6500/12942], Loss: 2.0168, Perplexity: 7.51443
# Epoch [3/3], Step [6600/12942], Loss: 2.1245, Perplexity: 8.36872
# Epoch [3/3], Step [6700/12942], Loss: 2.3578, Perplexity: 10.5676
# Epoch [3/3], Step [6800/12942], Loss: 1.8613, Perplexity: 6.43221
# Epoch [3/3], Step [6900/12942], Loss: 1.5320, Perplexity: 4.62733
# Epoch [3/3], Step [7000/12942], Loss: 1.7294, Perplexity: 5.63724
# Epoch [3/3], Step [7100/12942], Loss: 2.1324, Perplexity: 8.43507
# Epoch [3/3], Step [7200/12942], Loss: 2.0521, Perplexity: 7.78405
# Epoch [3/3], Step [7300/12942], Loss: 2.1386, Perplexity: 8.48745
# Epoch [3/3], Step [7400/12942], Loss: 2.0580, Perplexity: 7.83040
# Epoch [3/3], Step [7500/12942], Loss: 2.4918, Perplexity: 12.0836
# Epoch [3/3], Step [7600/12942], Loss: 1.8473, Perplexity: 6.34252
# Epoch [3/3], Step [7700/12942], Loss: 1.8630, Perplexity: 6.44321
# Epoch [3/3], Step [7800/12942], Loss: 1.9402, Perplexity: 6.96031
# Epoch [3/3], Step [7900/12942], Loss: 1.9454, Perplexity: 6.99671
# Epoch [3/3], Step [8000/12942], Loss: 1.8404, Perplexity: 6.29931
# Epoch [3/3], Step [8100/12942], Loss: 1.9966, Perplexity: 7.36407
# Epoch [3/3], Step [8200/12942], Loss: 2.1268, Perplexity: 8.38831
# Epoch [3/3], Step [8300/12942], Loss: 1.8467, Perplexity: 6.33871
# Epoch [3/3], Step [8400/12942], Loss: 2.0877, Perplexity: 8.06649
# Epoch [3/3], Step [8500/12942], Loss: 1.7850, Perplexity: 5.95983
# Epoch [3/3], Step [8600/12942], Loss: 1.7708, Perplexity: 5.87571
# Epoch [3/3], Step [8700/12942], Loss: 1.5093, Perplexity: 4.52361
# Epoch [3/3], Step [8800/12942], Loss: 1.9021, Perplexity: 6.70032
# Epoch [3/3], Step [8900/12942], Loss: 1.8328, Perplexity: 6.25155
# Epoch [3/3], Step [9000/12942], Loss: 1.6998, Perplexity: 5.47261
# Epoch [3/3], Step [9100/12942], Loss: 1.8516, Perplexity: 6.37032
# Epoch [3/3], Step [9200/12942], Loss: 2.0602, Perplexity: 7.84741
# Epoch [3/3], Step [9300/12942], Loss: 2.0920, Perplexity: 8.10106
# Epoch [3/3], Step [9400/12942], Loss: 1.9354, Perplexity: 6.92676
# Epoch [3/3], Step [9500/12942], Loss: 2.1884, Perplexity: 8.92071
# Epoch [3/3], Step [9600/12942], Loss: 1.7637, Perplexity: 5.83372
# Epoch [3/3], Step [9700/12942], Loss: 1.8123, Perplexity: 6.12451
# Epoch [3/3], Step [9800/12942], Loss: 1.8962, Perplexity: 6.66068
# Epoch [3/3], Step [9900/12942], Loss: 1.9730, Perplexity: 7.19262
# Epoch [3/3], Step [10000/12942], Loss: 1.7775, Perplexity: 5.9150
# Epoch [3/3], Step [10100/12942], Loss: 1.8825, Perplexity: 6.56980
# Epoch [3/3], Step [10200/12942], Loss: 1.9969, Perplexity: 7.36602
# Epoch [3/3], Step [10300/12942], Loss: 2.4740, Perplexity: 11.8696
# Epoch [3/3], Step [10400/12942], Loss: 1.8591, Perplexity: 6.41814
# Epoch [3/3], Step [10500/12942], Loss: 1.8500, Perplexity: 6.35975
# Epoch [3/3], Step [10600/12942], Loss: 2.0131, Perplexity: 7.48652
# Epoch [3/3], Step [10700/12942], Loss: 2.0451, Perplexity: 7.72990
# Epoch [3/3], Step [10800/12942], Loss: 1.9806, Perplexity: 7.24689
# Epoch [3/3], Step [10900/12942], Loss: 2.1397, Perplexity: 8.49650
# Epoch [3/3], Step [11000/12942], Loss: 1.7137, Perplexity: 5.54945
# Epoch [3/3], Step [11100/12942], Loss: 1.9319, Perplexity: 6.90270
# Epoch [3/3], Step [11200/12942], Loss: 1.7833, Perplexity: 5.94977
# Epoch [3/3], Step [11300/12942], Loss: 2.1141, Perplexity: 8.28181
# Epoch [3/3], Step [11400/12942], Loss: 1.9501, Perplexity: 7.02959
# Epoch [3/3], Step [11500/12942], Loss: 1.9830, Perplexity: 7.26433
# Epoch [3/3], Step [11600/12942], Loss: 1.8485, Perplexity: 6.35062
# Epoch [3/3], Step [11700/12942], Loss: 2.0597, Perplexity: 7.84357
# Epoch [3/3], Step [11800/12942], Loss: 1.7143, Perplexity: 5.55276
# Epoch [3/3], Step [11900/12942], Loss: 2.0665, Perplexity: 7.89699
# Epoch [3/3], Step [12000/12942], Loss: 1.7427, Perplexity: 5.71266
# Epoch [3/3], Step [12100/12942], Loss: 1.9902, Perplexity: 7.31714
# Epoch [3/3], Step [12200/12942], Loss: 1.7851, Perplexity: 5.96031
# Epoch [3/3], Step [12300/12942], Loss: 1.9295, Perplexity: 6.88580
# Epoch [3/3], Step [12400/12942], Loss: 1.8857, Perplexity: 6.59088
# Epoch [3/3], Step [12500/12942], Loss: 2.0487, Perplexity: 7.75828
# Epoch [3/3], Step [12600/12942], Loss: 1.9787, Perplexity: 7.23354
# Epoch [3/3], Step [12700/12942], Loss: 1.7610, Perplexity: 5.81832
# Epoch [3/3], Step [12800/12942], Loss: 1.8324, Perplexity: 6.24895
# Epoch [3/3], Step [12900/12942], Loss: 2.3963, Perplexity: 10.9826
# Epoch [3/3], Step [12942/12942], Loss: 1.9117, Perplexity: 6.7648

# %% [markdown]
# <a id='step3'></a>
# ## Step 3: (Optional) Validate your Model
#
# To assess potential overfitting, one approach is to assess performance on a validation set.  If you decide to do this **optional** task, you are required to first complete all of the steps in the next notebook in the sequence (**3_Inference.ipynb**); as part of that notebook, you will write and test code (specifically, the `sample` method in the `DecoderRNN` class) that uses your RNN decoder to generate captions.  That code will prove incredibly useful here.
#
# If you decide to validate your model, please do not edit the data loader in **data_loader.py**.  Instead, create a new file named **data_loader_val.py** containing the code for obtaining the data loader for the validation data.  You can access:
# - the validation images at filepath `'/opt/cocoapi/images/train2014/'`, and
# - the validation image caption annotation file at filepath `'/opt/cocoapi/annotations/captions_val2014.json'`.
#
# The suggested approach to validating your model involves creating a json file such as [this one](https://github.com/cocodataset/cocoapi/blob/master/results/captions_val2014_fakecap_results.json) containing your model's predicted captions for the validation images.  Then, you can write your own script or use one that you [find online](https://github.com/tylin/coco-caption) to calculate the BLEU score of your model.  You can read more about the BLEU score, along with other evaluation metrics (such as TEOR and Cider) in section 4.1 of [this paper](https://arxiv.org/pdf/1411.4555.pdf).  For more information about how to use the annotation file, check out the [website](http://cocodataset.org/#download) for the COCO dataset.

# %%
# (Optional) TODO: Validate your model.
